# %%
import os 
from PIL import Image
from torchvision.transforms import ToTensor,ToPILImage
from torchvision import transforms as T

# %%
to_tensor = ToTensor()
to_pil = ToPILImage()

# %%
dir = '/Users/zhezhouli/Repository/pytorch_learning/dogs_vs_cats'
os.chdir(dir)

# %%
img = 'data/train/cat.0.jpg'
cat = Image.open(img)
cat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374 at 0x11585BEF0>

# %%
transform = T.Compose([
    T.Resize(224),
    T.RandomCrop(224),
    T.ToTensor()
])

# %%
cat.size
# Out:
# (500, 374)

# %%
data = transform(cat)
to_pil(data)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x115A1A1D0>

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x115A1A390>

# %%
data
# Out:
# tensor([[[0.9529, 0.9569, 0.9569,  ..., 0.9725, 0.9725, 0.9725],
#          [0.9529, 0.9569, 0.9569,  ..., 0.9725, 0.9725, 0.9725],
#          [0.9529, 0.9569, 0.9569,  ..., 0.9765, 0.9765, 0.9765],
#          ...,
#          [0.2588, 0.2353, 0.2314,  ..., 0.0392, 0.0353, 0.0275],
#          [0.2510, 0.2235, 0.2196,  ..., 0.0353, 0.0314, 0.0235],
#          [0.2510, 0.2235, 0.2157,  ..., 0.0235, 0.0196, 0.0196]],
#
#         [[0.7843, 0.7882, 0.7882,  ..., 0.8980, 0.8941, 0.8941],
#          [0.7843, 0.7882, 0.7882,  ..., 0.8980, 0.8941, 0.8941],
#          [0.7843, 0.7882, 0.7882,  ..., 0.9020, 0.8980, 0.8980],
#          ...,
#          [0.1961, 0.1765, 0.1725,  ..., 0.0431, 0.0392, 0.0314],
#          [0.1922, 0.1647, 0.1608,  ..., 0.0392, 0.0353, 0.0275],
#          [0.1922, 0.1647, 0.1569,  ..., 0.0275, 0.0235, 0.0235]],
#
#         [[0.4745, 0.4784, 0.4784,  ..., 0.6039, 0.6078, 0.6078],
#          [0.4745, 0.4784, 0.4784,  ..., 0.6039, 0.6078, 0.6078],
#          [0.4745, 0.4784, 0.4784,  ..., 0.6078, 0.6118, 0.6118],
#          ...,
#          [0.0235, 0.0078, 0.0039,  ..., 0.0235, 0.0196, 0.0118],
#          [0.0157, 0.0039, 0.0000,  ..., 0.0196, 0.0157, 0.0078],
#          [0.0157, 0.0039, 0.0000,  ..., 0.0078, 0.0039, 0.0039]]])

# %%
random
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-5d64b71392b1> in <module>
# ----> 1 random
#
# NameError: name 'random' is not defined

# %%
from .AlexNet import AlexNet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-8ec17706a15b> in <module>
# ----> 1 from .AlexNet import AlexNet
#
# ModuleNotFoundError: No module named '__main__.AlexNet'; '__main__' is not a package

# %%
import fire
def add(x,y):
    return x + y
def mul(**kwargs):
    a = kwargs['a']
    b = kwargs['b']
    return a * b
fire.Fire()
# Out:
# ERROR: Cannot find key: -f
# Usage: ipykernel_launcher.py <group|command>
#   available groups:      In | Out | exit | quit | os | Image | T | fire
#   available commands:    get_ipython | ToTensor | ToPILImage | add | mul
#
# For detailed information on this command, run:
#   ipykernel_launcher.py --help
# An exception has occurred, use %tb to see the full traceback.
#
# FireExit: 2

# %%
def add(x,y):
    return x + y
def mul(**kwargs):
    a = kwargs['a']
    b = bwargs['b']
    return a * b

# %%
fire.Fire()
# Out:
# ERROR: Cannot find key: -f
# Usage: ipykernel_launcher.py <group|command|value>
#   available groups:      In | Out | exit | quit | os | Image | T | fire
#   available commands:    get_ipython | ToTensor | ToPILImage | add | mul
#   available values:      a
#
# For detailed information on this command, run:
#   ipykernel_launcher.py --help
# An exception has occurred, use %tb to see the full traceback.
#
# FireExit: 2

# %%
# !ls
# Out:
# checkpoints data        models      utils
# config.py   main.py     test.ipynb
